# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data.csv', sep=';')

# %%
data = data.sort_values('cells')
data = data[data['cells'] > 0]
data
# Out:
#          cells       bytes  build_duration_nanosec  retr_duration_avg_nanosec  \
# 168       9123      880375              7375047359                        226
# 145     108898    12386741             10771180228                        492
# 84      125507    14521274              8984330074                        186
# 79      160941    19153806              9524871800                        180
# 108     165373    19772546             10982198535                        182
# ..         ...         ...                     ...                        ...
# 51   258178635  2397949019            138852040638                       1773
# 50   263675726  2444890264            147976208716                       2477
# 14   263675726  2444890264            147976208716                       2477
# 49   269161612  2491760969            148811310676                       1097
# 13   269161612  2491760969            148811310676                       1097
#
#        algorithm                          table
# 168  dedup_btree                 main_tokenized
# 145  dedup_btree                 main_tokenized
# 84    dedup_hash                 main_tokenized
# 79    dedup_hash                 main_tokenized
# 108   dedup_hash                 main_tokenized
# ..           ...                            ...
# 51            ns  open_data_mate_main_tokenized
# 50            ns  open_data_mate_main_tokenized
# 14            ns  open_data_mate_main_tokenized
# 49            ns  open_data_mate_main_tokenized
# 13            ns  open_data_mate_main_tokenized
#
# [194 rows x 6 columns]

# %%
fig, ax = plt.subplots()

# %%
from math import log
import numpy as np
ax.clear()



def plot_mem(data, att, value):
    data = data[data[att] == value]
    x = data['cells']
    y = data['bytes']


    ax.set_ylabel("memory [byte]")
    ax.set_xlabel("table cells")
    return ax.plot(x, y)


data_ns = data[data['algorithm'] ==  'ns']
plot_mem(data_ns, 'table', 'main_tokenized')[0].set_label("main_tokenized")
plot_mem(data_ns, 'table', 'open_data_mate_main_tokenized')[0].set_label("open data")
ax.legend()


fig

# %% [markdown]
# the memory footprint is heavily dependant on the dataset at hand.

# %%
data[data['algorithm'] == 'dedup_btree']
# Out:
#        cells       bytes  build_duration_nanosec  retr_duration_avg_nanosec  \
# 168     9123      880375              7375047359                        226
# 145   108898    12386741             10771180228                        492
# 136   186038    22629274             13353594010                        605
# 156   231342    29073709             12812319818                        722
# 140   295921    38701474             16636508820                        908
# ..       ...         ...                     ...                        ...
# 179  9641219  4994221991             61424712105                       1822
# 191  9647776  4998210610             62065052631                       2780
# 182  9884177  5157176713             64329121489                       1938
# 181  9913214  5176627957             65888931352                       2077
# 185  9939266  5194276560             62263266212                       2840
#
#        algorithm                          table
# 168  dedup_btree                 main_tokenized
# 145  dedup_btree                 main_tokenized
# 136  dedup_btree                 main_tokenized
# 156  dedup_btree                 main_tokenized
# 140  dedup_btree                 main_tokenized
# ..           ...                            ...
# 179  dedup_btree  open_data_mate_main_tokenized
# 191  dedup_btree  open_data_mate_main_tokenized
# 182  dedup_btree  open_data_mate_main_tokenized
# 181  dedup_btree  open_data_mate_main_tokenized
# 185  dedup_btree  open_data_mate_main_tokenized
#
# [73 rows x 6 columns]

# %%
ax.clear()

#data_mt = data[data['table'] == 'main_tokenized']
def memplot(data):
    
    a, = plot_mem(data, 'algorithm', 'ns')
    a.set_label("ns + dedup")
    a, = plot_mem(data, 'algorithm', 'baseline')
    a.set_label("baseline")
    a, = plot_mem(data, 'algorithm', 'dedup_btree')
    a.set_label("dedup")
    
    ax.set_title("memory footprint of diff. algorithms")
    
    ax.legend()
memplot(data)
fig

# %%
data[data['algorithm'] == 'dedup_btree']
# Out:
#        cells       bytes  build_duration_nanosec  retr_duration_avg_nanosec  \
# 168     9123      880375              7375047359                        226
# 145   108898    12386741             10771180228                        492
# 136   186038    22629274             13353594010                        605
# 156   231342    29073709             12812319818                        722
# 140   295921    38701474             16636508820                        908
# ..       ...         ...                     ...                        ...
# 179  9641219  4994221991             61424712105                       1822
# 191  9647776  4998210610             62065052631                       2780
# 182  9884177  5157176713             64329121489                       1938
# 181  9913214  5176627957             65888931352                       2077
# 185  9939266  5194276560             62263266212                       2840
#
#        algorithm                          table
# 168  dedup_btree                 main_tokenized
# 145  dedup_btree                 main_tokenized
# 136  dedup_btree                 main_tokenized
# 156  dedup_btree                 main_tokenized
# 140  dedup_btree                 main_tokenized
# ..           ...                            ...
# 179  dedup_btree  open_data_mate_main_tokenized
# 191  dedup_btree  open_data_mate_main_tokenized
# 182  dedup_btree  open_data_mate_main_tokenized
# 181  dedup_btree  open_data_mate_main_tokenized
# 185  dedup_btree  open_data_mate_main_tokenized
#
# [73 rows x 6 columns]

# %%
data[data['algorithm'] == 'baseline']
# Out:
#        cells       bytes  build_duration_nanosec  retr_duration_avg_nanosec  \
# 71  25380477  1056217579             11217057079                         49
# 35  25380477  1056217579             11217057079                         49
# 70  50765891  2112606144             14272857455                         55
# 34  50765891  2112606144             14272857455                         55
# 33  60912463  2534841654             15036811580                         58
# 69  60912463  2534841654             15036811580                         58
# 68  71069903  2957519601             14896401738                         45
# 32  71069903  2957519601             14896401738                         45
# 67  81222630  3380065053             16036352935                         45
# 31  81222630  3380065053             16036352935                         45
# 30  86299603  3591297839             16488825742                         67
# 66  86299603  3591297839             16488825742                         67
# 29  91373969  3802482688             17135666715                         52
# 65  91373969  3802482688             17135666715                         52
# 64  93403038  3886927778             16917005025                         55
# 28  93403038  3886927778             16917005025                         55
# 63  95433225  3971405451             16885178604                         59
# 27  95433225  3971405451             16885178604                         59
# 26  97465484  4055988608             18195063513                         48
# 62  97465484  4055988608             18195063513                         48
# 25  99497290  4140549528             18370949745                         49
# 61  99497290  4140549528             18370949745                         49
#
#    algorithm           table
# 71  baseline  main_tokenized
# 35  baseline  main_tokenized
# 70  baseline  main_tokenized
# 34  baseline  main_tokenized
# 33  baseline  main_tokenized
# 69  baseline  main_tokenized
# 68  baseline  main_tokenized
# 32  baseline  main_tokenized
# 67  baseline  main_tokenized
# 31  baseline  main_tokenized
# 30  baseline  main_tokenized
# 66  baseline  main_tokenized
# 29  baseline  main_tokenized
# 65  baseline  main_tokenized
# 64  baseline  main_tokenized
# 28  baseline  main_tokenized
# 63  baseline  main_tokenized
# 27  baseline  main_tokenized
# 26  baseline  main_tokenized
# 62  baseline  main_tokenized
# 25  baseline  main_tokenized
# 61  baseline  main_tokenized

# %%
tables = ["main_tokenized", "open_data_mate_main_tokenized"]
algos = ["baseline", "ns", "dedup_hash", "dedup_btree"]

# %%
ax.clear()
for table in tables:
    for algorithm in algos:
        d = data
        d = d[d["table"] == table]
        d = d[d["algorithm"] == algorithm]
        cellcount = d['cells']
        retr_time = d['retr_duration_avg_nanosec']
        ax.plot(cellcount, retr_time, marker="x", label=f"{algorithm} {table}")

ax.set_ylabel("averaged retrieval time [nanosecs]")
ax.set_xlabel("cell count")
ax.set_title("retrieval time with respect to cell amount")
ax.legend()
fig
