# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tdata = pd.read_csv('./tableinfo.csv', sep=";")
tdata
# Out:
#                            table      values  distinct_values  \
# 0            mate_main_tokenized    37849251                0
# 1       main_tokenized_embedding    87700361           768260
# 2                 main_tokenized   101529655           768260
# 3           cocoa_main_tokenized   112772902           768260
# 4  open_data_mate_main_tokenized   274658645          9940801
# 5       open_data_main_tokenized   799930934         19776045
# 6       gittables_main_tokenized  1588021298         97488581
#
#    mean_cardinality  avg_cell_len   avg_tableid   avg_colid     avg_rowid
# 0               inf      0.000000  7.257179e+07    4.684806  1.528314e+02
# 1        114.154532      1.711494  6.775167e+07    9.074454  5.946968e+01
# 2        132.155332      1.614582  6.977859e+07    9.646693  5.257549e+01
# 3        146.790022      1.553309  7.500609e+07    9.732021  5.942166e+01
# 4         27.629428      8.696761  5.185624e+03  682.581300  6.013763e+04
# 5         40.449490      7.986371  9.939454e+03  267.581213  1.058475e+06
# 6         16.289306     12.468851  8.494823e+05   18.848094  4.767343e+02

# %%
compdata = pd.read_csv('./compression-data.csv', sep=";")
compdata.sort_values('cells', ascending=False)
compdata
# Out:
#          cells        bytes  build_duration_nanosec  \
# 0    129382144   2884688704             14704040631
# 1    177291144   6044203616             31843971692
# 2     20848596     49247384              2241269823
# 3     31872963     57941920              3194626385
# 4     95722960    145751056              8007490220
# ..         ...          ...                     ...
# 654   54935271    760431808              9497137529
# 655   27469763    391850152              5199311726
# 656   27470572    392042528              5202047684
# 657  274658645   3323047312             29391296868
# 658  799930934  16595224960             63378254350
#
#      build_duration_total_nanosec  retr_duration_avg_nanosec    algorithm  \
# 0                     79835824915                        830   dedup_hash
# 1                    350500281099                        690   dedup_hash
# 2                     16105632414                        365           ns
# 3                     21426254255                        727  dedup_btree
# 4                     28699350078                       1025  dedup_btree
# ..                            ...                        ...          ...
# 654                   62315574573                        478           ns
# 655                   53737518726                        450           ns
# 656                   54204000736                        400           ns
# 657                   69197929430                        635           ns
# 658                  227743035721                       1076   dedup_hash
#
#                              table
# 0    open_data_mate_main_tokenized
# 1         gittables_main_tokenized
# 2         main_tokenized_embedding
# 3             cocoa_main_tokenized
# 4             cocoa_main_tokenized
# ..                             ...
# 654  open_data_mate_main_tokenized
# 655  open_data_mate_main_tokenized
# 656  open_data_mate_main_tokenized
# 657  open_data_mate_main_tokenized
# 658       open_data_main_tokenized
#
# [659 rows x 7 columns]

# %%
compdata['bytes_per_cell'] = compdata['bytes'] / compdata['cells']
compdata
# Out:
#          cells        bytes  build_duration_nanosec  \
# 0    129382144   2884688704             14704040631
# 1    177291144   6044203616             31843971692
# 2     20848596     49247384              2241269823
# 3     31872963     57941920              3194626385
# 4     95722960    145751056              8007490220
# ..         ...          ...                     ...
# 654   54935271    760431808              9497137529
# 655   27469763    391850152              5199311726
# 656   27470572    392042528              5202047684
# 657  274658645   3323047312             29391296868
# 658  799930934  16595224960             63378254350
#
#      build_duration_total_nanosec  retr_duration_avg_nanosec    algorithm  \
# 0                     79835824915                        830   dedup_hash
# 1                    350500281099                        690   dedup_hash
# 2                     16105632414                        365           ns
# 3                     21426254255                        727  dedup_btree
# 4                     28699350078                       1025  dedup_btree
# ..                            ...                        ...          ...
# 654                   62315574573                        478           ns
# 655                   53737518726                        450           ns
# 656                   54204000736                        400           ns
# 657                   69197929430                        635           ns
# 658                  227743035721                       1076   dedup_hash
#
#                              table  bytes_per_cell
# 0    open_data_mate_main_tokenized       22.295880
# 1         gittables_main_tokenized       34.091966
# 2         main_tokenized_embedding        2.362144
# 3             cocoa_main_tokenized        1.817902
# 4             cocoa_main_tokenized        1.522634
# ..                             ...             ...
# 654  open_data_mate_main_tokenized       13.842324
# 655  open_data_mate_main_tokenized       14.264781
# 656  open_data_mate_main_tokenized       14.271364
# 657  open_data_mate_main_tokenized       12.098827
# 658       open_data_main_tokenized       20.745822
#
# [659 rows x 8 columns]

# %%
def flatten(ii):
    for i in ii:
        for elem in i:
            yield elem


fig, axss = plt.subplots(2, 2, figsize=(20, 15))
axs = list(flatten(axss))

# lets see if the bytes per cell are stable per algorithm and table
i = 0
for algo, arow in compdata.groupby('algorithm'):
    ax = axs[i]
    i+=1
    ax.set_title(algo)
    ax.set_xlabel('cell count')
    ax.set_ylabel('bytes per cell')

    for table, row in arow.groupby('table'):
        ax.scatter('cells', 'bytes_per_cell', data=row, label=table)

    ax.legend()

# %%
# per (algorithm x table) we want the average bytes per cell

# the compression rate is than on (algorithm x table) baseline.bytespercell / a.x.t.bytespercell


# average bytes per cell for all algorithms and tables
bpc = dict()

for axt, row in compdata.groupby(['algorithm', 'table']):
    # calculate average bytes per cell
    bpc[axt] = row['bytes_per_cell'].mean()

compressionrate = dict()
for [algo, table], value in bpc.items():
    cr = bpc[('baseline', table)] / value
    compressionrate[ ( algo, table ) ] = cr

# %%
tables = list(set(compdata['table']))
algos = list(set(compdata['algorithm']))
algos.sort()
algos
# Out:
# ['baseline', 'dedup_btree', 'dedup_hash', 'ns']

# %%
fig, ax = plt.subplots(figsize=(15, 12))

w = 0.1
x = np.arange(len(algos))
offset = 0.35
for table in tables:
    rates = list(map(lambda algo: compressionrate[(algo, table)], algos))

    ax.bar(x - offset, rates, width=w, label=table)
    offset += w

ax.legend()
ax.set_title('compression per algorithm')
ax.set_ylabel('compression rate')
ax.set_xlabel('algorithms')
ax.xaxis.set_ticks(x, algos)

fig.tight_layout()
